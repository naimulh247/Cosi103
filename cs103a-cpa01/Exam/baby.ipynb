# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
babydf = pd.read_csv('baby-names.csv').to_dict()
babydf.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/vagrant/jupyter_dir/Cosi103/cs103a-cpa01/Exam/baby.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bu20_04_personal/home/vagrant/jupyter_dir/Cosi103/cs103a-cpa01/Exam/baby.ipynb#ch0000001vscode-remote?line=0'>1</a> babydf = pd.read_csv('baby-names.csv').to_dict()
#       <a href='vscode-notebook-cell://ssh-remote%2Bu20_04_personal/home/vagrant/jupyter_dir/Cosi103/cs103a-cpa01/Exam/baby.ipynb#ch0000001vscode-remote?line=1'>2</a> babydf.head
#
# NameError: name 'pd' is not defined

# %%
namept = babydf.pivot_table( columns="name", index="year", values="percent")
namept['Timothy']
# Out:
# year
# 1880    0.000591
# 1881    0.000582
# 1882    0.000582
# 1883    0.000551
# 1884    0.000627
#           ...
# 2004    0.002474
# 2005    0.002363
# 2006    0.002139
# 2007    0.001997
# 2008    0.001864
# Name: Timothy, Length: 129, dtype: float64

# %%
y = babydf['name'].str.contains('Timothy').value_counts()
y1 = babydf[babydf['name'].str.contains('John')].value_counts()
y2 = babydf[babydf['name'].str.contains('Maria')].value_counts()

x = babydf['year']
namept.plot()

# plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/vagrant/jupyter_dir/Cosi103/cs103a-cpa01/Exam/baby.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2Bu20_04_personal/home/vagrant/jupyter_dir/Cosi103/cs103a-cpa01/Exam/baby.ipynb#ch0000008vscode-remote?line=2'>3</a> y2 = babydf[babydf['name'].str.contains('Maria')].value_counts()
#       <a href='vscode-notebook-cell://ssh-remote%2Bu20_04_personal/home/vagrant/jupyter_dir/Cosi103/cs103a-cpa01/Exam/baby.ipynb#ch0000008vscode-remote?line=4'>5</a> x = babydf['year']
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bu20_04_personal/home/vagrant/jupyter_dir/Cosi103/cs103a-cpa01/Exam/baby.ipynb#ch0000008vscode-remote?line=5'>6</a> namept.plot()
#
# File ~/jupyter_dir/jupyter_env/lib/python3.8/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
# ...
